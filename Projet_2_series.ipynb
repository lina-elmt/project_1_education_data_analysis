# %% [markdown]
# # Series décrit les différentes variables étudiées. Chaque variable est déclinée selon l'âge, le sexe, le niveau d'études ...

# %% [markdown]
# ## Series va nous permettre de sélectionner un premier échantillon de variables les plus pertinentes pour notre étude.

# %%
import pandas as pd
import numpy as np

# %%
series = pd.read_csv("EdStatsSeries.csv")

# %%
series.head()
# Out:
#            Series Code       Topic  \
# 0  BAR.NOED.1519.FE.ZS  Attainment
# 1     BAR.NOED.1519.ZS  Attainment
# 2  BAR.NOED.15UP.FE.ZS  Attainment
# 3     BAR.NOED.15UP.ZS  Attainment
# 4  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unit of measure  \
# ...

# %%
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3665 entries, 0 to 3664
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Series Code                          3665 non-null   object
#  1   Topic                                3665 non-null   object
#  2   Indicator Name                       3665 non-null   object
#  3   Short definition                     2156 non-null   object
#  4   Long definition                      3665 non-null   object
#  5   Unit of measure                      0 non-null      float64
#  6   Periodicity                          99 non-null     object
#  7   Base Period                          314 non-null    object
#  8   Other notes                          552 non-null    object
#  9   Aggregation method                   47 non-null     object
#  10  Limitations and exceptions           14 non-null     object
# ...

# %%
series = series[series["Indicator Name"].str.contains("male|female|25+|30|35|40|45|50|60|65|70|75|80|Africa Dataset|Drop-out|drop-out|Percentage|percentage|percent|early childhood|literacy|Teachers") == False]

# %%
pd.set_option("display.max_rows", 2000)

# %%
series['Indicator Name']
# Out:
# 30      Barro-Lee: Population in thousands, age 15-19,...
# 32      Barro-Lee: Population in thousands, age 15+, t...
# 34      Barro-Lee: Population in thousands, age 20-24,...
# 50      Barro-Lee: Population in thousands, age 55-59,...
# 120     Barro-Lee: Average years of primary schooling,...
# 122     Barro-Lee: Average years of primary schooling,...
# 124     Barro-Lee: Average years of primary schooling,...
# 140     Barro-Lee: Average years of primary schooling,...
# 150     Barro-Lee: Average years of total schooling, a...
# 152     Barro-Lee: Average years of total schooling, a...
# 154     Barro-Lee: Average years of total schooling, a...
# 170     Barro-Lee: Average years of total schooling, a...
# 240     Barro-Lee: Average years of secondary schoolin...
# 242     Barro-Lee: Average years of secondary schoolin...
# 244     Barro-Lee: Average years of secondary schoolin...
# 260     Barro-Lee: Average years of secondary schoolin...
# ...

# %%
series.loc[1987,:]
# Out:
# Series Code                                                             PRJ.POP.ALL.4.MF
# Topic                                                                         Attainment
# Indicator Name                         Projection: Population in thousands by highest...
# Short definition                                                                     NaN
# Long definition                        Total population in thousands that has complet...
# Unit of measure                                                                      NaN
# Periodicity                                                                          NaN
# Base Period                                                   Projections (2010 to 2100)
# Other notes                                                                          NaN
# Aggregation method                                                                   NaN
# ...

# %%
series_selection = series.loc[[611,1662,2825,2332,2589]]

# %%
series_selection = series_selection[['Series Code','Topic', 'Indicator Name','Long definition','Source']]
series_selection
# Out:
#            Series Code                                              Topic  \
# 611     IT.NET.USER.P2                     Infrastructure: Communications
# 1662    NY.GDP.PCAP.CD  Economic Policy & Debt: National accounts: US$...
# 1987  PRJ.POP.ALL.4.MF                                         Attainment
# 2825           UIS.E.3                                          Secondary
# 2332       SE.TER.ENRL                                           Tertiary
# 2216       SE.COM.DURS                                         Background
# 2589       SP.POP.GROW                       Health: Population: Dynamics
#
#                                          Indicator Name  \
# 611                     Internet users (per 100 people)
# 1662                       GDP per capita (current US$)
# 1987  Projection: Population in thousands by highest...
# 2825  Enrolment in upper secondary education, both s...
# 2332  Enrolment in tertiary education, all programme...
# ...

# %%
variables = series_selection['Series Code']
# %store variables

# %%
variables
